# %%
import pickle
import glob
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
import xgboost as xgb

# load feats
train_x,test_x = [],[]
for feat in sorted(glob.glob('../features/*.pkl')):
#     if 'tfidf' in feat or 'lr' in feat or 'mnb' in feat:
#         continue
    print('file path',feat)
    a,b = pickle.load(open(feat,'rb'))
    print(a.shape,b.shape)
    train_x.append(a)
    test_x.append(b)
train_x = np.nan_to_num(np.hstack(train_x))
test_x = np.nan_to_num(np.hstack(test_x))
print(train_x.shape)
    
# load y
train = pd.read_csv("../input/train.csv")
list_classes = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
train_y = train[list_classes].values.astype('int')
print(train_x.shape)
# Out:
# /home/jac/.local/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# file path ../features/cnn_glove_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_glove_2_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_gru_glove_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_gru_glove_1_trainable_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_gru_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_muse_adj_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_muse_adj_1_feat_de_fr.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_muse_adj_2_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/gru_glove_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/gru_glove_1_trainable_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/gru_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lr_feat1.pkl
# (95851, 6) (226998, 6)
# file path ../features/lr_feat2.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_2_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_glove_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_glove_1_trainable_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj2_add_de_fr_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj3_add_de_fr_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj_1_add_de_fr_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj_2_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj_bn_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/mnb_feat1.pkl
# (95851, 6) (226998, 6)
# file path ../features/mnb_feat2.pkl
# (95851, 6) (226998, 6)
# file path ../features/other_feat.pkl
# (95851, 16) (226998, 16)
# file path ../features/simple_rnn_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/tfidf_feat1.pkl
# (95851, 30) (226998, 30)
# file path ../features/tfidf_feat2.pkl
# (95851, 30) (226998, 30)
# (95851, 244)
# (95851, 244)

# %%
from sklearn.model_selection import KFold,StratifiedKFold
def simple_ens(model_name,k=3,rnd=233):
    kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=rnd)
    test_pred = np.zeros((226998,6))
    cache_test_pred = np.zeros((226998,6))
    single_best = 100
    single_best_pred = None
    all_train_loss_l,all_val_loss_l = 0,0
    
    for train_index, test_index in kf.split(train_x,train_y[:,2]): # stratified on 3 column
        # x,y
        curr_x,curr_y = train_x[train_index],train_y[train_index]
        hold_out_x,hold_out_y = train_x[test_index],train_y[test_index]
        val_loss_l,train_loss_l = 0,0
        d_test = xgb.DMatrix(test_x)
        
        # share params
        params = {
                'colsample_bytree': 0.9,
                'subsample': 0.9,
                'eta': 0.05,
                'max_depth': 3,
                'eval_metric':'logloss',
                'objective':'binary:logistic',
                'scale_pos_weight':0.85,
                'colsample_bylevel':0.9,
                'colsample_bytree':0.9,
            
                }
        
        # train for each class
        for i in range(6):
            d_train = xgb.DMatrix(curr_x, curr_y[:,i])
            d_valid = xgb.DMatrix(hold_out_x, hold_out_y[:,i])
            watchlist = [(d_train, 'train'), (d_valid, 'valid')]

            model = xgb.train(params, d_train, 1000, watchlist,
                              early_stopping_rounds=50,
                            verbose_eval=2000)
            print(i)
            try:
                curr_train_loss = log_loss(curr_y[:,i],model.predict(d_train))
                curr_val_loss = log_loss(hold_out_y[:,i],model.predict(d_valid))
                print(curr_train_loss,curr_val_loss)
                val_loss_l += curr_val_loss
                train_loss_l += curr_train_loss
            except:
                pass
            curr_test_pred = model.predict(d_test)
            
            test_pred[:,i] += curr_test_pred
            cache_test_pred[:,i] += curr_test_pred
            
        # avg 6 class
        train_loss_l = train_loss_l/6
        val_loss_l = val_loss_l/6
        print('this fold avg train',train_loss_l,'avg val',val_loss_l)
        
        # save best one fold result
        if val_loss_l < single_best:
            single_best = single_best
            single_best_pred = cache_test_pred
            print('new single best')
        
        cache_test_pred = np.zeros((226998,6))
        
        # avg k fold
        all_train_loss_l += train_loss_l/k
        all_val_loss_l += val_loss_l/k
        print('========================')
    test_pred = test_pred/k
    print('all train avg',all_train_loss_l,'all val avg',all_val_loss_l)
    return test_pred, single_best_pred

print('done')
# Out:
# done

# %%
xgb_res,b = simple_ens('xgb',k=5)
sample_submission = pd.read_csv("../input/sample_submission.csv")
sample_submission[list_classes] = xgb_res
sample_submission.to_csv("../results/xgb_adj_params_ens_new_csv_fold5.gz", index=False, compression='gzip')
print(sample_submission.head())
print('save done')
# Out:
# [0]	train-logloss:0.649328	valid-logloss:0.649196
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [370]	train-logloss:0.070307	valid-logloss:0.079558
#
# 0
# 0.0688082066608 0.0796030536829
# [0]	train-logloss:0.645628	valid-logloss:0.645665
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [236]	train-logloss:0.015671	valid-logloss:0.020946
#
# 1
# 0.0143997409658 0.021049757152
# [0]	train-logloss:0.64691	valid-logloss:0.646974
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [239]	train-logloss:0.035828	valid-logloss:0.043624
#
# 2
# 0.0342161103788 0.0437404153324
# [0]	train-logloss:0.64473	valid-logloss:0.644865
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [173]	train-logloss:0.004113	valid-logloss:0.010831
#
# 3
# 0.00332593086432 0.0110767681583
# [0]	train-logloss:0.647824	valid-logloss:0.647897
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [295]	train-logloss:0.047942	valid-logloss:0.057727
#
# 4
# 0.0463212139237 0.0578360544384
# [0]	train-logloss:0.645348	valid-logloss:0.645352
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [231]	train-logloss:0.013754	valid-logloss:0.017252
#
# 5
# 0.0126242874657 0.0172905013489
# this fold avg train 0.0299492483765 avg val 0.0384327583521
# new single best
# ========================
# [0]	train-logloss:0.649335	valid-logloss:0.649322
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [387]	train-logloss:0.069692	valid-logloss:0.07895
#
# 0
# 0.0680722089343 0.0789950059936
# [0]	train-logloss:0.64564	valid-logloss:0.645664
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [225]	train-logloss:0.016074	valid-logloss:0.020313
#
# 1
# 0.0148620197383 0.0203835469427
# [0]	train-logloss:0.646917	valid-logloss:0.646906
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [158]	train-logloss:0.038924	valid-logloss:0.042498
#
# 2
# 0.0370780043208 0.0426293900055
# [0]	train-logloss:0.644775	valid-logloss:0.644805
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [192]	train-logloss:0.004523	valid-logloss:0.007157
#
# 3
# 0.00363240935119 0.00722157688141
# [0]	train-logloss:0.647838	valid-logloss:0.648045
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [192]	train-logloss:0.051225	valid-logloss:0.058889
#
# 4
# 0.0494117251606 0.0590604956409
# [0]	train-logloss:0.645339	valid-logloss:0.645371
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [191]	train-logloss:0.0143	valid-logloss:0.019855
#
# 5
# 0.0130301889917 0.0199490796011
# this fold avg train 0.0310144260828 avg val 0.0380398491775
# new single best
# ========================
# [0]	train-logloss:0.649233	valid-logloss:0.6495
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [427]	train-logloss:0.066913	valid-logloss:0.087369
#
# 0
# 0.0653149179251 0.0874580446474
# [0]	train-logloss:0.645594	valid-logloss:0.645717
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [182]	train-logloss:0.016522	valid-logloss:0.024066
#
# 1
# 0.0152717925773 0.0241642472256
# [0]	train-logloss:0.646894	valid-logloss:0.646951
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [202]	train-logloss:0.037055	valid-logloss:0.04333
#
# 2
# 0.0353123638224 0.0434601041141
# [0]	train-logloss:0.644794	valid-logloss:0.644763
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [237]	train-logloss:0.003912	valid-logloss:0.007102
#
# 3
# 0.00319094513908 0.00718956477031
# [0]	train-logloss:0.647787	valid-logloss:0.647882
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [325]	train-logloss:0.046609	valid-logloss:0.059115
#
# 4
# 0.0451028217905 0.0592207245194
# [0]	train-logloss:0.645346	valid-logloss:0.645401
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [174]	train-logloss:0.014871	valid-logloss:0.019326
#
# 5
# 0.0135639605588 0.0194221908596
# this fold avg train 0.0296261336355 avg val 0.0401524793561
# new single best
# ========================
# [0]	train-logloss:0.649309	valid-logloss:0.649251
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [373]	train-logloss:0.06945	valid-logloss:0.080496
#
# 0
# 0.06796677787 0.0805793481615
# [0]	train-logloss:0.645645	valid-logloss:0.645592
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [212]	train-logloss:0.016366	valid-logloss:0.020671
#
# 1
# 0.015097531416 0.0208037405368
# [0]	train-logloss:0.646904	valid-logloss:0.646919
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [251]	train-logloss:0.035583	valid-logloss:0.042966
#
# 2
# 0.033997784827 0.0430587061011
# [0]	train-logloss:0.644789	valid-logloss:0.644771
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [205]	train-logloss:0.004475	valid-logloss:0.006141
#
# 3
# 0.00368095692054 0.00621158253498
# [0]	train-logloss:0.647885	valid-logloss:0.647765
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [175]	train-logloss:0.052675	valid-logloss:0.05524
#
# 4
# 0.0509215270741 0.0552723542132
# [0]	train-logloss:0.645351	valid-logloss:0.645371
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [193]	train-logloss:0.014813	valid-logloss:0.017933
#
# 5
# 0.0135528613418 0.0180032905897
# this fold avg train 0.0308695732416 avg val 0.0373215036895
# new single best
# ========================
# [0]	train-logloss:0.649203	valid-logloss:0.649416
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [253]	train-logloss:0.072991	valid-logloss:0.085571
#
# 0
# 0.0711269696849 0.0856037308877
# [0]	train-logloss:0.645621	valid-logloss:0.645687
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [181]	train-logloss:0.01691	valid-logloss:0.021649
#
# 1
# 0.0155586161074 0.0217366277417
# [0]	train-logloss:0.646914	valid-logloss:0.646987
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [216]	train-logloss:0.036235	valid-logloss:0.044277
#
# 2
# 0.0346549828919 0.0443063433033
# [0]	train-logloss:0.644762	valid-logloss:0.644811
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [207]	train-logloss:0.003985	valid-logloss:0.008526
#
# 3
# 0.00328822714792 0.00860274992824
# [0]	train-logloss:0.647865	valid-logloss:0.647868
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [328]	train-logloss:0.047082	valid-logloss:0.056021
#
# 4
# 0.0455346978063 0.0560725307036
# [0]	train-logloss:0.645311	valid-logloss:0.645368
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [176]	train-logloss:0.014418	valid-logloss:0.020554
#
# 5
# 0.0132189868272 0.020605240088
# this fold avg train 0.0305637467443 avg val 0.0394878704421
# new single best
# ========================
# all train avg 0.0304046256162 all val avg 0.0386868922035
#          id     toxic  severe_toxic   obscene    threat    insult  \
# 0   6044863  0.001528      0.000041  0.000360  0.000031  0.001490
# 1   6102620  0.000522      0.000033  0.000096  0.000029  0.000078
# 2  14563293  0.000224      0.000050  0.000106  0.000051  0.000126
# 3  21086297  0.001111      0.000041  0.000319  0.000041  0.000241
# 4  22982444  0.002148      0.000054  0.000679  0.000042  0.000490
#
#    identity_hate
# 0       0.000171
# 1       0.000065
# 2       0.000193
# 3       0.000092
# 4       0.000074
# save done

# %%
# xgb_res,b = simple_ens('xgb',k=8)
# sample_submission = pd.read_csv("../input/sample_submission.csv")
# sample_submission[list_classes] = xgb_res
# sample_submission.to_csv("../results/xgb_ens_new_csv_fold8.gz", index=False, compression='gzip')
# print(sample_submission.head())
# print('save done')
