# %%
# ref: https://www.kaggle.com/jacklinggu/lstm-with-glove-embedding-public-lb-score-0-049

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re
from keras.models import Model, load_model
from keras.layers import Dense, Embedding, Input, GRU
from keras.layers import LSTM, Bidirectional, GlobalMaxPool1D, Dropout,GlobalAveragePooling1D,Conv1D
from keras.preprocessing import text, sequence
from keras.callbacks import EarlyStopping, ModelCheckpoint

max_features = 40000
maxlen = 150

def clean_text( text ):
    text = text.lower().split()
    text = " ".join(text)
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+\-=]", " ", text)
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)
    #
    return text

train = pd.read_csv("../input/train.csv")
test = pd.read_csv("../input/test.csv")

list_sentences_train = train["comment_text"].fillna("CVxTz").apply(clean_text).values
list_classes = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
y = train[list_classes].values
list_sentences_test = test["comment_text"].fillna("CVxTz").apply(clean_text).values
print(y.shape)
# Out:
# Using TensorFlow backend.
# (159571, 6)

# %%
list_sentences_train[:5]
# Out:
# array([ 'explanation why the edits made under my username hardcore metallica fan were reverted they were not vandalisms just closure on some gas after i voted at new york dolls fac and please do not remove the template from the talk page since i am retired now 89 205 38 27',
#        'd aww ! he matches this background colour i am seemingly stuck with thanks talk 21 51 january 11 2016 utc ',
#        'hey man i am really not trying to edit war it just that this guy is constantly removing relevant information and talking to me through edits instead of my talk page he seems to care more about the formatting than the actual info ',
#        ' more i cannot make any real suggestions on improvement - i wondered if the section statistics should be later on or a subsection of types of accidents - i think the references may need tidying so that they are all in the exact same format ie date format etc i can do that later on if no - one else does first - if you have any preferences for formatting style on references or want to do it yourself please let me know there appears to be a backlog on articles for review so i guess there may be a delay until a reviewer turns up it listed in the relevant form eg wikipedia good article nominations transport ',
#        'you sir are my hero any chance you remember what page that on '], dtype=object)

# %%
print('test len',len(test))
# Out:
# test len 153164

# %%
tokenizer = text.Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(list_sentences_train))
list_tokenized_train = tokenizer.texts_to_sequences(list_sentences_train)
list_tokenized_test = tokenizer.texts_to_sequences(list_sentences_test)
X_train = sequence.pad_sequences(list_tokenized_train, maxlen=maxlen)
X_test = sequence.pad_sequences(list_tokenized_test, maxlen=maxlen)

print(X_train.shape,X_test.shape)
# Out:
# (159571, 150) (153164, 150)

# %%
# check word_index
tmp_cnt = 0
for k in tokenizer.word_index:
    print(k,tokenizer.word_index[k])
    tmp_cnt += 1
    if tmp_cnt >5:
        break
word_idx = tokenizer.word_index
# Out:
# wp1ny3upexc 119062
# rated 5510
# thenachoman 91216
# xysys 133932
# weren 25524
# wondering 1211

# %%
# read word2vec
# 
word_vec_dict = {}
with open('../glove.840B.300d.txt') as f:
    for line in f:
        v_list = line.strip().split(' ')
        k = str(v_list[0])
        v = np.array([float(x) for x in v_list[1:]])
        word_vec_dict[k] = v
print(len(word_vec_dict))
print('Preparing embedding matrix')
EMBEDDING_DIM = 300
nb_words = min(max_features,len(word_idx))
embedding_matrix = np.zeros((nb_words, EMBEDDING_DIM))
for word,i in word_idx.items():
    if i >= max_features:
        continue
    else:
        if word in word_vec_dict:
            embedding_matrix[i] = word_vec_dict[word]
print('Null word embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))
del word_vec_dict
# Out:
# 2196007
# Preparing embedding matrix
# Null word embeddings: 3388

# %%
from sklearn.metrics import log_loss,accuracy_score

def eval_val(y,train_x):
    res = 0
    acc_res = 0
    for i in range(6):
        curr_loss = log_loss(y[:,i],train_x[:,i])
        acc = accuracy_score(y[:,i],train_x[:,i].round())
        print(i,curr_loss,acc)
        res += curr_loss
        acc_res += acc
    print('final',res/6, acc_res/6)

def get_model():
    # add dropout
    inp = Input(shape=(maxlen, ))
    x = Embedding(nb_words, EMBEDDING_DIM, weights=[embedding_matrix],trainable=False)(inp)
    x = Dropout(0.2)(x)
    x = Bidirectional(GRU(64, return_sequences=True, dropout=0.2, recurrent_dropout=0.2))(x)
    x = GlobalMaxPool1D()(x)
    x = Dropout(0.1)(x)
    x = Dense(256, activation="relu")(x)
    x = Dropout(0.1)(x)
    x = Dense(6, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

    return model
print('def model done')
# Out:
# def model done

# %%
from sklearn.utils import shuffle

def del_data_ratio(x,y,ratio=0.8):
    pos_index = np.where(y[:,0]==1)[0]
    neg_index = np.where(y[:,0]==0)[0]
    #print(pos_index)
    data_cnt = len(pos_index)
    add_cnt = int(data_cnt*ratio)
    add_index = pos_index[:add_cnt]
    add_x = np.concatenate([x[add_index],x[neg_index]])
    add_y = np.concatenate([y[add_index],y[neg_index]])
    print(x.shape,add_x.shape,data_cnt)
    add_x,add_y = shuffle(add_x,add_y,random_state=6)
    return add_x,add_y

from sklearn.model_selection import KFold
def kf_train(fold_cnt=3,rnd=1):
    kf = KFold(n_splits=fold_cnt, shuffle=False, random_state=233*rnd)
    train_pred, test_pred = np.zeros((159571,6)),np.zeros((153164,6))
    for train_index, test_index in kf.split(X_train):
        # x,y
        curr_x,curr_y = X_train[train_index],y[train_index]
        hold_out_x,hold_out_y = X_train[test_index],y[test_index]
        
        # change pos ratio
        new_curr_x,new_curr_y = del_data_ratio(curr_x,curr_y)
        new_hold_x,new_hold_y = del_data_ratio(hold_out_x,hold_out_y)
        
        # model
        model = get_model()
        batch_size = 256
        epochs = 8
        file_path="weights_base.best.h5"
        checkpoint = ModelCheckpoint(file_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
        callbacks_list = [checkpoint] 
        
        # train and pred
        model.fit(new_curr_x, new_curr_y, 
                  batch_size=batch_size, epochs=epochs, 
                  validation_data=(new_hold_x,new_hold_y), 
                  callbacks=callbacks_list)
        
        model = load_model(file_path)
        y_test = model.predict(X_test)
        test_pred += y_test
        hold_out_pred = model.predict(hold_out_x)
        train_pred[test_index] = hold_out_pred
    test_pred = test_pred / fold_cnt
    print('-------------------------------')
    print('all eval',eval_val(y,train_pred))
    return train_pred, test_pred


print('def done')
# Out:
# def done

# %%
import pickle
sample_submission = pd.read_csv("../input/sample_submission.csv")

for f in [3,4]:
    train_pred,test_pred = kf_train(fold_cnt=f,rnd=f)
    print(train_pred.shape,test_pred.shape)    
    sample_submission[list_classes] = test_pred
    sample_submission.to_csv("../results/gru1_glove_sample_{}.gz".format(f), index=False, compression='gzip')
    with open('../features/gru1_glove_sample_feat_{}.pkl'.format(f),'wb') as fout:
        pickle.dump([train_pred,test_pred],fout)
    sample_submission.head()
    print('===================================')
# Out:
# (106380, 150) (104358, 150) 10110
# (53191, 150) (52154, 150) 5184
# Train on 104358 samples, validate on 52154 samples
# Epoch 1/8
# 104192/104358 [============================>.] - ETA: 0s - loss: 0.0697 - acc: 0.9787Epoch 00001: val_loss improved from inf to 0.04762, saving model to weights_base.best.h5
# 104358/104358 [==============================] - 134s 1ms/step - loss: 0.0696 - acc: 0.9788 - val_loss: 0.0476 - val_acc: 0.9820
# Epoch 2/8
# 104192/104358 [============================>.] - ETA: 0s - loss: 0.0435 - acc: 0.9842Epoch 00002: val_loss improved from 0.04762 to 0.03997, saving model to weights_base.best.h5
# 104358/104358 [==============================] - 133s 1ms/step - loss: 0.0434 - acc: 0.9842 - val_loss: 0.0400 - val_acc: 0.9847
# Epoch 3/8
# 104192/104358 [============================>.] - ETA: 0s - loss: 0.0409 - acc: 0.9848Epoch 00003: val_loss improved from 0.03997 to 0.03834, saving model to weights_base.best.h5
# 104358/104358 [==============================] - 133s 1ms/step - loss: 0.0409 - acc: 0.9848 - val_loss: 0.0383 - val_acc: 0.9854
# Epoch 4/8
# 104192/104358 [============================>.] - ETA: 0s - loss: 0.0387 - acc: 0.9855Epoch 00004: val_loss improved from 0.03834 to 0.03808, saving model to weights_base.best.h5
# 104358/104358 [==============================] - 133s 1ms/step - loss: 0.0387 - acc: 0.9855 - val_loss: 0.0381 - val_acc: 0.9854
# Epoch 5/8
# 104192/104358 [============================>.] - ETA: 0s - loss: 0.0375 - acc: 0.9858Epoch 00005: val_loss improved from 0.03808 to 0.03669, saving model to weights_base.best.h5
# 104358/104358 [==============================] - 134s 1ms/step - loss: 0.0375 - acc: 0.9858 - val_loss: 0.0367 - val_acc: 0.9859
# Epoch 6/8
# 104192/104358 [============================>.] - ETA: 0s - loss: 0.0368 - acc: 0.9861Epoch 00006: val_loss did not improve
# 104358/104358 [==============================] - 135s 1ms/step - loss: 0.0368 - acc: 0.9861 - val_loss: 0.0400 - val_acc: 0.9846
# Epoch 7/8
# 104192/104358 [============================>.] - ETA: 0s - loss: 0.0357 - acc: 0.9864Epoch 00007: val_loss did not improve
# 104358/104358 [==============================] - 135s 1ms/step - loss: 0.0357 - acc: 0.9864 - val_loss: 0.0373 - val_acc: 0.9855
# Epoch 8/8
# 104192/104358 [============================>.] - ETA: 0s - loss: 0.0348 - acc: 0.9866Epoch 00008: val_loss improved from 0.03669 to 0.03623, saving model to weights_base.best.h5
# 104358/104358 [==============================] - 136s 1ms/step - loss: 0.0348 - acc: 0.9866 - val_loss: 0.0362 - val_acc: 0.9858
# (106381, 150) (104330, 150) 10252
# (53190, 150) (52181, 150) 5042
# Train on 104330 samples, validate on 52181 samples
# Epoch 1/8
# 104192/104330 [============================>.] - ETA: 0s - loss: 0.0710 - acc: 0.9777Epoch 00001: val_loss improved from inf to 0.04415, saving model to weights_base.best.h5
# 104330/104330 [==============================] - 136s 1ms/step - loss: 0.0709 - acc: 0.9778 - val_loss: 0.0441 - val_acc: 0.9840
# Epoch 2/8
# 104192/104330 [============================>.] - ETA: 0s - loss: 0.0442 - acc: 0.9840Epoch 00002: val_loss improved from 0.04415 to 0.04039, saving model to weights_base.best.h5
# 104330/104330 [==============================] - 135s 1ms/step - loss: 0.0442 - acc: 0.9840 - val_loss: 0.0404 - val_acc: 0.9849
# Epoch 3/8
# 104192/104330 [============================>.] - ETA: 0s - loss: 0.0411 - acc: 0.9848Epoch 00003: val_loss improved from 0.04039 to 0.03937, saving model to weights_base.best.h5
# 104330/104330 [==============================] - 135s 1ms/step - loss: 0.0411 - acc: 0.9848 - val_loss: 0.0394 - val_acc: 0.9854
# Epoch 4/8
# 104192/104330 [============================>.] - ETA: 0s - loss: 0.0393 - acc: 0.9852Epoch 00004: val_loss improved from 0.03937 to 0.03730, saving model to weights_base.best.h5
# 104330/104330 [==============================] - 135s 1ms/step - loss: 0.0393 - acc: 0.9852 - val_loss: 0.0373 - val_acc: 0.9859
# Epoch 5/8
# 104192/104330 [============================>.] - ETA: 0s - loss: 0.0382 - acc: 0.9856Epoch 00005: val_loss improved from 0.03730 to 0.03682, saving model to weights_base.best.h5
# 104330/104330 [==============================] - 135s 1ms/step - loss: 0.0382 - acc: 0.9856 - val_loss: 0.0368 - val_acc: 0.9861
# Epoch 6/8
# 104192/104330 [============================>.] - ETA: 0s - loss: 0.0370 - acc: 0.9859Epoch 00006: val_loss improved from 0.03682 to 0.03608, saving model to weights_base.best.h5
# 104330/104330 [==============================] - 135s 1ms/step - loss: 0.0370 - acc: 0.9859 - val_loss: 0.0361 - val_acc: 0.9863
# Epoch 7/8
# 104192/104330 [============================>.] - ETA: 0s - loss: 0.0360 - acc: 0.9861Epoch 00007: val_loss improved from 0.03608 to 0.03593, saving model to weights_base.best.h5
# 104330/104330 [==============================] - 135s 1ms/step - loss: 0.0360 - acc: 0.9861 - val_loss: 0.0359 - val_acc: 0.9862
# Epoch 8/8
# 104192/104330 [============================>.] - ETA: 0s - loss: 0.0353 - acc: 0.9865Epoch 00008: val_loss improved from 0.03593 to 0.03580, saving model to weights_base.best.h5
# 104330/104330 [==============================] - 136s 1ms/step - loss: 0.0353 - acc: 0.9865 - val_loss: 0.0358 - val_acc: 0.9863
# (106381, 150) (104335, 150) 10226
# (53190, 150) (52176, 150) 5068
# Train on 104335 samples, validate on 52176 samples
# Epoch 1/8
# 104192/104335 [============================>.] - ETA: 0s - loss: 0.0689 - acc: 0.9791Epoch 00001: val_loss improved from inf to 0.04405, saving model to weights_base.best.h5
# 104335/104335 [==============================] - 137s 1ms/step - loss: 0.0688 - acc: 0.9791 - val_loss: 0.0441 - val_acc: 0.9843
# Epoch 2/8
# 104192/104335 [============================>.] - ETA: 0s - loss: 0.0440 - acc: 0.9839Epoch 00002: val_loss improved from 0.04405 to 0.03990, saving model to weights_base.best.h5
# 104335/104335 [==============================] - 136s 1ms/step - loss: 0.0440 - acc: 0.9839 - val_loss: 0.0399 - val_acc: 0.9848
# Epoch 3/8
# 104192/104335 [============================>.] - ETA: 0s - loss: 0.0409 - acc: 0.9848Epoch 00003: val_loss improved from 0.03990 to 0.03830, saving model to weights_base.best.h5
# 104335/104335 [==============================] - 136s 1ms/step - loss: 0.0409 - acc: 0.9848 - val_loss: 0.0383 - val_acc: 0.9854
# Epoch 4/8
# 104192/104335 [============================>.] - ETA: 0s - loss: 0.0391 - acc: 0.9852Epoch 00004: val_loss did not improve
# 104335/104335 [==============================] - 137s 1ms/step - loss: 0.0391 - acc: 0.9852 - val_loss: 0.0427 - val_acc: 0.9832
# Epoch 5/8
# 104192/104335 [============================>.] - ETA: 0s - loss: 0.0378 - acc: 0.9857Epoch 00005: val_loss improved from 0.03830 to 0.03740, saving model to weights_base.best.h5
# 104335/104335 [==============================] - 133s 1ms/step - loss: 0.0378 - acc: 0.9857 - val_loss: 0.0374 - val_acc: 0.9858
# Epoch 6/8
# 104192/104335 [============================>.] - ETA: 0s - loss: 0.0366 - acc: 0.9860Epoch 00006: val_loss did not improve
# 104335/104335 [==============================] - 133s 1ms/step - loss: 0.0366 - acc: 0.9861 - val_loss: 0.0390 - val_acc: 0.9850
# Epoch 7/8
# 104192/104335 [============================>.] - ETA: 0s - loss: 0.0356 - acc: 0.9862Epoch 00007: val_loss improved from 0.03740 to 0.03708, saving model to weights_base.best.h5
# 104335/104335 [==============================] - 133s 1ms/step - loss: 0.0356 - acc: 0.9862 - val_loss: 0.0371 - val_acc: 0.9856
# Epoch 8/8
# 104192/104335 [============================>.] - ETA: 0s - loss: 0.0350 - acc: 0.9865Epoch 00008: val_loss did not improve
# 104335/104335 [==============================] - 133s 1ms/step - loss: 0.0350 - acc: 0.9865 - val_loss: 0.0376 - val_acc: 0.9856
# -------------------------------
# 0 0.091102763201 0.964949771575
# 1 0.0222364211058 0.990054583853
# 2 0.0466860172543 0.98197667496
# 3 0.0100518214445 0.997060869456
# 4 0.0606425382071 0.97473851765
# 5 0.0199350410681 0.992774376296
# final 0.0417757670468 0.983592465632
# all eval None
# (159571, 6) (153164, 6)
# ===================================
# (119678, 150) (117406, 150) 11359
# (39893, 150) (39106, 150) 3935
# Train on 117406 samples, validate on 39106 samples
# Epoch 1/8
# 117248/117406 [============================>.] - ETA: 0s - loss: 0.0694 - acc: 0.9780Epoch 00001: val_loss improved from inf to 0.04382, saving model to weights_base.best.h5
# 117406/117406 [==============================] - 141s 1ms/step - loss: 0.0693 - acc: 0.9780 - val_loss: 0.0438 - val_acc: 0.9837
# Epoch 2/8
# 117248/117406 [============================>.] - ETA: 0s - loss: 0.0434 - acc: 0.9843Epoch 00002: val_loss improved from 0.04382 to 0.04004, saving model to weights_base.best.h5
# 117406/117406 [==============================] - 145s 1ms/step - loss: 0.0434 - acc: 0.9843 - val_loss: 0.0400 - val_acc: 0.9847
# Epoch 3/8
# 117248/117406 [============================>.] - ETA: 0s - loss: 0.0406 - acc: 0.9850Epoch 00003: val_loss improved from 0.04004 to 0.03992, saving model to weights_base.best.h5
# 117406/117406 [==============================] - 138s 1ms/step - loss: 0.0406 - acc: 0.9850 - val_loss: 0.0399 - val_acc: 0.9846
# Epoch 4/8
# 117248/117406 [============================>.] - ETA: 0s - loss: 0.0386 - acc: 0.9856Epoch 00004: val_loss improved from 0.03992 to 0.03761, saving model to weights_base.best.h5
# 117406/117406 [==============================] - 138s 1ms/step - loss: 0.0386 - acc: 0.9856 - val_loss: 0.0376 - val_acc: 0.9857
# Epoch 5/8
# 117248/117406 [============================>.] - ETA: 0s - loss: 0.0376 - acc: 0.9857Epoch 00005: val_loss did not improve
# 117406/117406 [==============================] - 138s 1ms/step - loss: 0.0376 - acc: 0.9856 - val_loss: 0.0381 - val_acc: 0.9852
# Epoch 6/8
# 117248/117406 [============================>.] - ETA: 0s - loss: 0.0361 - acc: 0.9862Epoch 00006: val_loss did not improve
# 117406/117406 [==============================] - 138s 1ms/step - loss: 0.0361 - acc: 0.9862 - val_loss: 0.0383 - val_acc: 0.9848
# Epoch 7/8
# 117248/117406 [============================>.] - ETA: 0s - loss: 0.0350 - acc: 0.9865Epoch 00007: val_loss improved from 0.03761 to 0.03725, saving model to weights_base.best.h5
# 117406/117406 [==============================] - 138s 1ms/step - loss: 0.0350 - acc: 0.9865 - val_loss: 0.0373 - val_acc: 0.9854
# Epoch 8/8
# 117248/117406 [============================>.] - ETA: 0s - loss: 0.0345 - acc: 0.9866Epoch 00008: val_loss improved from 0.03725 to 0.03634, saving model to weights_base.best.h5
# 117406/117406 [==============================] - 140s 1ms/step - loss: 0.0344 - acc: 0.9866 - val_loss: 0.0363 - val_acc: 0.9856
# (119678, 150) (117381, 150) 11482
# (39893, 150) (39130, 150) 3812
# Train on 117381 samples, validate on 39130 samples
# Epoch 1/8
# 117248/117381 [============================>.] - ETA: 0s - loss: 0.0726 - acc: 0.9756Epoch 00001: val_loss improved from inf to 0.04262, saving model to weights_base.best.h5
# 117381/117381 [==============================] - 141s 1ms/step - loss: 0.0725 - acc: 0.9756 - val_loss: 0.0426 - val_acc: 0.9846
# Epoch 2/8
# 117248/117381 [============================>.] - ETA: 0s - loss: 0.0435 - acc: 0.9842Epoch 00002: val_loss improved from 0.04262 to 0.03992, saving model to weights_base.best.h5
# 117381/117381 [==============================] - 139s 1ms/step - loss: 0.0435 - acc: 0.9842 - val_loss: 0.0399 - val_acc: 0.9852
# Epoch 3/8
# 117248/117381 [============================>.] - ETA: 0s - loss: 0.0404 - acc: 0.9849Epoch 00003: val_loss improved from 0.03992 to 0.03793, saving model to weights_base.best.h5
# 117381/117381 [==============================] - 139s 1ms/step - loss: 0.0404 - acc: 0.9849 - val_loss: 0.0379 - val_acc: 0.9859
# Epoch 4/8
# 117248/117381 [============================>.] - ETA: 0s - loss: 0.0388 - acc: 0.9855Epoch 00004: val_loss improved from 0.03793 to 0.03739, saving model to weights_base.best.h5
# 117381/117381 [==============================] - 139s 1ms/step - loss: 0.0388 - acc: 0.9855 - val_loss: 0.0374 - val_acc: 0.9861
# Epoch 5/8
# 117248/117381 [============================>.] - ETA: 0s - loss: 0.0371 - acc: 0.9858Epoch 00005: val_loss improved from 0.03739 to 0.03710, saving model to weights_base.best.h5
# 117381/117381 [==============================] - 139s 1ms/step - loss: 0.0371 - acc: 0.9858 - val_loss: 0.0371 - val_acc: 0.9860
# Epoch 6/8
# 117248/117381 [============================>.] - ETA: 0s - loss: 0.0363 - acc: 0.9860Epoch 00006: val_loss did not improve
# 117381/117381 [==============================] - 139s 1ms/step - loss: 0.0363 - acc: 0.9860 - val_loss: 0.0376 - val_acc: 0.9857
# Epoch 7/8
# 117248/117381 [============================>.] - ETA: 0s - loss: 0.0354 - acc: 0.9862Epoch 00007: val_loss improved from 0.03710 to 0.03617, saving model to weights_base.best.h5
# 117381/117381 [==============================] - 139s 1ms/step - loss: 0.0354 - acc: 0.9862 - val_loss: 0.0362 - val_acc: 0.9863
# Epoch 8/8
# 117248/117381 [============================>.] - ETA: 0s - loss: 0.0348 - acc: 0.9863Epoch 00008: val_loss did not improve
# 117381/117381 [==============================] - 139s 1ms/step - loss: 0.0348 - acc: 0.9863 - val_loss: 0.0373 - val_acc: 0.9857
# (119678, 150) (117363, 150) 11575
# (39893, 150) (39149, 150) 3719
# Train on 117363 samples, validate on 39149 samples
# Epoch 1/8
# 117248/117363 [============================>.] - ETA: 0s - loss: 0.0661 - acc: 0.9788Epoch 00001: val_loss improved from inf to 0.04067, saving model to weights_base.best.h5
# 117363/117363 [==============================] - 138s 1ms/step - loss: 0.0660 - acc: 0.9788 - val_loss: 0.0407 - val_acc: 0.9854
# Epoch 2/8
# 117248/117363 [============================>.] - ETA: 0s - loss: 0.0434 - acc: 0.9841Epoch 00002: val_loss did not improve
# 117363/117363 [==============================] - 136s 1ms/step - loss: 0.0434 - acc: 0.9841 - val_loss: 0.0415 - val_acc: 0.9844
# Epoch 3/8
# 117248/117363 [============================>.] - ETA: 0s - loss: 0.0406 - acc: 0.9849Epoch 00003: val_loss improved from 0.04067 to 0.03663, saving model to weights_base.best.h5
# 117363/117363 [==============================] - 136s 1ms/step - loss: 0.0406 - acc: 0.9849 - val_loss: 0.0366 - val_acc: 0.9863
# Epoch 4/8
# 117248/117363 [============================>.] - ETA: 0s - loss: 0.0390 - acc: 0.9854Epoch 00004: val_loss did not improve
# 117363/117363 [==============================] - 136s 1ms/step - loss: 0.0391 - acc: 0.9854 - val_loss: 0.0388 - val_acc: 0.9851
# Epoch 5/8
# 117248/117363 [============================>.] - ETA: 0s - loss: 0.0375 - acc: 0.9857Epoch 00005: val_loss improved from 0.03663 to 0.03536, saving model to weights_base.best.h5
# 117363/117363 [==============================] - 136s 1ms/step - loss: 0.0374 - acc: 0.9857 - val_loss: 0.0354 - val_acc: 0.9866
# Epoch 6/8
# 117248/117363 [============================>.] - ETA: 0s - loss: 0.0366 - acc: 0.9859Epoch 00006: val_loss did not improve
# 117363/117363 [==============================] - 136s 1ms/step - loss: 0.0366 - acc: 0.9859 - val_loss: 0.0359 - val_acc: 0.9863
# Epoch 7/8
# 117248/117363 [============================>.] - ETA: 0s - loss: 0.0355 - acc: 0.9863Epoch 00007: val_loss did not improve
# 117363/117363 [==============================] - 136s 1ms/step - loss: 0.0355 - acc: 0.9863 - val_loss: 0.0357 - val_acc: 0.9862
# Epoch 8/8
# 117248/117363 [============================>.] - ETA: 0s - loss: 0.0348 - acc: 0.9865Epoch 00008: val_loss improved from 0.03536 to 0.03464, saving model to weights_base.best.h5
# 117363/117363 [==============================] - 136s 1ms/step - loss: 0.0348 - acc: 0.9865 - val_loss: 0.0346 - val_acc: 0.9866
# (119679, 150) (117385, 150) 11466
# (39892, 150) (39126, 150) 3828
# Train on 117385 samples, validate on 39126 samples
# Epoch 1/8
# 117248/117385 [============================>.] - ETA: 0s - loss: 0.0681 - acc: 0.9786Epoch 00001: val_loss improved from inf to 0.04679, saving model to weights_base.best.h5
# 117385/117385 [==============================] - 140s 1ms/step - loss: 0.0680 - acc: 0.9786 - val_loss: 0.0468 - val_acc: 0.9825
# Epoch 2/8
# 117248/117385 [============================>.] - ETA: 0s - loss: 0.0430 - acc: 0.9841Epoch 00002: val_loss improved from 0.04679 to 0.03989, saving model to weights_base.best.h5
# 117385/117385 [==============================] - 137s 1ms/step - loss: 0.0430 - acc: 0.9841 - val_loss: 0.0399 - val_acc: 0.9851
# Epoch 3/8
# 117248/117385 [============================>.] - ETA: 0s - loss: 0.0399 - acc: 0.9850Epoch 00003: val_loss improved from 0.03989 to 0.03875, saving model to weights_base.best.h5
# 117385/117385 [==============================] - 137s 1ms/step - loss: 0.0399 - acc: 0.9850 - val_loss: 0.0388 - val_acc: 0.9852
# Epoch 4/8
# 117248/117385 [============================>.] - ETA: 0s - loss: 0.0380 - acc: 0.9856Epoch 00004: val_loss improved from 0.03875 to 0.03806, saving model to weights_base.best.h5
# 117385/117385 [==============================] - 137s 1ms/step - loss: 0.0379 - acc: 0.9856 - val_loss: 0.0381 - val_acc: 0.9856
# Epoch 5/8
# 117248/117385 [============================>.] - ETA: 0s - loss: 0.0368 - acc: 0.9858Epoch 00005: val_loss did not improve
# 117385/117385 [==============================] - 137s 1ms/step - loss: 0.0368 - acc: 0.9858 - val_loss: 0.0389 - val_acc: 0.9851
# Epoch 6/8
# 117248/117385 [============================>.] - ETA: 0s - loss: 0.0358 - acc: 0.9862Epoch 00006: val_loss improved from 0.03806 to 0.03696, saving model to weights_base.best.h5
# 117385/117385 [==============================] - 137s 1ms/step - loss: 0.0358 - acc: 0.9862 - val_loss: 0.0370 - val_acc: 0.9858
# Epoch 7/8
# 117248/117385 [============================>.] - ETA: 0s - loss: 0.0353 - acc: 0.9864Epoch 00007: val_loss did not improve
# 117385/117385 [==============================] - 137s 1ms/step - loss: 0.0353 - acc: 0.9864 - val_loss: 0.0370 - val_acc: 0.9860
# Epoch 8/8
# 117248/117385 [============================>.] - ETA: 0s - loss: 0.0344 - acc: 0.9867Epoch 00008: val_loss did not improve
# 117385/117385 [==============================] - 137s 1ms/step - loss: 0.0345 - acc: 0.9867 - val_loss: 0.0373 - val_acc: 0.9857
# -------------------------------
# 0 0.0910659361612 0.965125242055
# 1 0.0222843233429 0.990324056376
# 2 0.0461651140342 0.982559487626
# 3 0.00879226779643 0.997123537485
# 4 0.0599760698812 0.974876387313
# 5 0.0198142795724 0.993037582017
# final 0.0413496651314 0.983841048812
# all eval None
# (159571, 6) (153164, 6)
# ===================================
