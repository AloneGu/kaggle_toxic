# %%
import pickle
import glob
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
import xgboost as xgb

# load feats
train_x,test_x = [],[]
for feat in sorted(glob.glob('../features/*.pkl')):
#     if 'tfidf' in feat or 'lr' in feat or 'mnb' in feat:
#         continue
    print('file path',feat)
    a,b = pickle.load(open(feat,'rb'))
    print(a.shape,b.shape)
    train_x.append(a)
    test_x.append(b)
train_x = np.nan_to_num(np.hstack(train_x))
test_x = np.nan_to_num(np.hstack(test_x))
print(train_x.shape)
    
# load y
train = pd.read_csv("../input/train.csv")
list_classes = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
train_y = train[list_classes].values.astype('int')
print(train_x.shape)
# Out:
# /home/jac/.local/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# file path ../features/cnn_glove_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_gru_glove_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_gru_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_muse_adj_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_muse_adj_1_feat_de_fr.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_muse_adj_2_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/gru_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lr_feat1.pkl
# (95851, 6) (226998, 6)
# file path ../features/lr_feat2.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_2_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_glove_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj2_add_de_fr_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj3_add_de_fr_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj_1_add_de_fr_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj_2_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj_bn_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/mnb_feat1.pkl
# (95851, 6) (226998, 6)
# file path ../features/mnb_feat2.pkl
# (95851, 6) (226998, 6)
# file path ../features/other_feat.pkl
# (95851, 16) (226998, 16)
# file path ../features/simple_rnn_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/tfidf_feat1.pkl
# (95851, 30) (226998, 30)
# file path ../features/tfidf_feat2.pkl
# (95851, 30) (226998, 30)
# (95851, 214)
# (95851, 214)

# %%
from sklearn.model_selection import KFold,StratifiedKFold
def simple_ens(model_name,k=3,rnd=233):
    kf = StratifiedKFold(n_splits=k, shuffle=True, random_state=rnd)
    test_pred = np.zeros((226998,6))
    cache_test_pred = np.zeros((226998,6))
    single_best = 100
    single_best_pred = None
    all_train_loss_l,all_val_loss_l = 0,0
    
    for train_index, test_index in kf.split(train_x,train_y[:,2]): # stratified on 3 column
        # x,y
        curr_x,curr_y = train_x[train_index],train_y[train_index]
        hold_out_x,hold_out_y = train_x[test_index],train_y[test_index]
        val_loss_l,train_loss_l = 0,0
        d_test = xgb.DMatrix(test_x)
        
        # share params
        params = {
                'colsample_bytree': 0.9,
                'subsample': 0.9,
                'eta': 0.05,
                'max_depth': 3,
                'eval_metric':'logloss',
                'objective':'binary:logistic',
                'scale_pos_weight':0.9,
                'colsample_bylevel':0.9,
                'colsample_bytree':0.9,
            
                }
        
        # train for each class
        for i in range(6):
            d_train = xgb.DMatrix(curr_x, curr_y[:,i])
            d_valid = xgb.DMatrix(hold_out_x, hold_out_y[:,i])
            watchlist = [(d_train, 'train'), (d_valid, 'valid')]

            model = xgb.train(params, d_train, 1000, watchlist,
                              early_stopping_rounds=50,
                            verbose_eval=2000)
            print(i)
            try:
                curr_train_loss = log_loss(curr_y[:,i],model.predict(d_train))
                curr_val_loss = log_loss(hold_out_y[:,i],model.predict(d_valid))
                print(curr_train_loss,curr_val_loss)
                val_loss_l += curr_val_loss
                train_loss_l += curr_train_loss
            except:
                pass
            curr_test_pred = model.predict(d_test)
            
            test_pred[:,i] += curr_test_pred
            cache_test_pred[:,i] += curr_test_pred
            
        # avg 6 class
        train_loss_l = train_loss_l/6
        val_loss_l = val_loss_l/6
        print('this fold avg train',train_loss_l,'avg val',val_loss_l)
        
        # save best one fold result
        if val_loss_l < single_best:
            single_best = val_loss_l
            single_best_pred = cache_test_pred
            print('new single best')
        
        cache_test_pred = np.zeros((226998,6))
        
        # avg k fold
        all_train_loss_l += train_loss_l/k
        all_val_loss_l += val_loss_l/k
        print('========================')
    test_pred = test_pred/k
    print('all train avg',all_train_loss_l,'all val avg',all_val_loss_l)
    return test_pred, single_best_pred

print('done')
# Out:
# done

# %%
xgb_res,b = simple_ens('xgb',k=5)
sample_submission = pd.read_csv("../input/sample_submission.csv")
sample_submission[list_classes] = xgb_res
sample_submission.to_csv("../results/xgb_adj_params_ens_new_csv_fold5.gz", index=False, compression='gzip')
print(sample_submission.head())
print('save done')
# Out:
# [0]	train-logloss:0.649346	valid-logloss:0.649248
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [439]	train-logloss:0.068914	valid-logloss:0.079735
#
# 0
# 0.0674929425646 0.0797892197409
# [0]	train-logloss:0.645644	valid-logloss:0.645673
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [209]	train-logloss:0.016611	valid-logloss:0.02082
#
# 1
# 0.0152843208472 0.0208220665004
# [0]	train-logloss:0.646932	valid-logloss:0.646969
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [183]	train-logloss:0.038335	valid-logloss:0.043329
#
# 2
# 0.0365411770808 0.0433740283659
# [0]	train-logloss:0.644736	valid-logloss:0.644863
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [166]	train-logloss:0.004429	valid-logloss:0.010878
#
# 3
# 0.0035970830217 0.0111204974663
# [0]	train-logloss:0.647855	valid-logloss:0.647933
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [302]	train-logloss:0.048306	valid-logloss:0.058085
#
# 4
# 0.0468913083898 0.0581552952398
# [0]	train-logloss:0.64537	valid-logloss:0.645358
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [283]	train-logloss:0.012938	valid-logloss:0.017073
#
# 5
# 0.0118867314403 0.0171710535794
# this fold avg train 0.0302822605574 avg val 0.0384053601488
# new single best
# ========================
# [0]	train-logloss:0.649356	valid-logloss:0.649358
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [387]	train-logloss:0.070421	valid-logloss:0.080132
#
# 0
# 0.0688700657866 0.0801579055789
# [0]	train-logloss:0.64566	valid-logloss:0.645718
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [208]	train-logloss:0.016526	valid-logloss:0.020148
#
# 1
# 0.0151646415932 0.0202608693663
# [0]	train-logloss:0.646937	valid-logloss:0.646922
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [189]	train-logloss:0.038393	valid-logloss:0.042128
#
# 2
# 0.0366706641276 0.0422352076473
# [0]	train-logloss:0.644781	valid-logloss:0.644797
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [188]	train-logloss:0.004729	valid-logloss:0.007085
#
# 3
# 0.00386314491512 0.00718682920628
# [0]	train-logloss:0.647846	valid-logloss:0.648034
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [292]	train-logloss:0.048578	valid-logloss:0.059454
#
# 4
# 0.0470937379049 0.0595392135948
# [0]	train-logloss:0.645347	valid-logloss:0.64538
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [154]	train-logloss:0.015363	valid-logloss:0.020219
#
# 5
# 0.0139997988161 0.0202732542394
# this fold avg train 0.0309436755239 avg val 0.0382755466055
# ========================
# [0]	train-logloss:0.649261	valid-logloss:0.649512
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [364]	train-logloss:0.069714	valid-logloss:0.08673
#
# 0
# 0.0680495720105 0.0867423145914
# [0]	train-logloss:0.645614	valid-logloss:0.645732
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [161]	train-logloss:0.017132	valid-logloss:0.023846
#
# 1
# 0.0159256160616 0.0239849164389
# [0]	train-logloss:0.646909	valid-logloss:0.646915
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [208]	train-logloss:0.03704	valid-logloss:0.043795
#
# 2
# 0.0354421284411 0.0438757963837
# [0]	train-logloss:0.644802	valid-logloss:0.644788
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [163]	train-logloss:0.005184	valid-logloss:0.007302
#
# 3
# 0.00434026018754 0.00738092382562
# [0]	train-logloss:0.647818	valid-logloss:0.647902
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [230]	train-logloss:0.050224	valid-logloss:0.059192
#
# 4
# 0.0485623306011 0.059277245008
# [0]	train-logloss:0.645357	valid-logloss:0.645397
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [169]	train-logloss:0.01508	valid-logloss:0.019619
#
# 5
# 0.0138319844328 0.019724627359
# this fold avg train 0.0310253152891 avg val 0.0401643039344
# ========================
# [0]	train-logloss:0.649369	valid-logloss:0.649298
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [361]	train-logloss:0.07086	valid-logloss:0.081104
#
# 0
# 0.0694140561731 0.0811675112525
# [0]	train-logloss:0.645658	valid-logloss:0.645626
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [164]	train-logloss:0.017846	valid-logloss:0.020697
#
# 1
# 0.0164757355355 0.020757226929
# [0]	train-logloss:0.646937	valid-logloss:0.646953
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [195]	train-logloss:0.038039	valid-logloss:0.043429
#
# 2
# 0.036326741783 0.0434419430722
# [0]	train-logloss:0.644807	valid-logloss:0.64479
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [259]	train-logloss:0.003765	valid-logloss:0.00592
#
# 3
# 0.00309550163346 0.0060338350904
# [0]	train-logloss:0.647924	valid-logloss:0.647836
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [181]	train-logloss:0.053089	valid-logloss:0.05597
#
# 4
# 0.051217362382 0.0559797563323
# [0]	train-logloss:0.645366	valid-logloss:0.6454
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [192]	train-logloss:0.014888	valid-logloss:0.018025
#
# 5
# 0.0136667645894 0.018105633774
# this fold avg train 0.0316993603494 avg val 0.0375809844084
# ========================
# [0]	train-logloss:0.649304	valid-logloss:0.649503
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [254]	train-logloss:0.073673	valid-logloss:0.085688
#
# 0
# 0.0720094506056 0.0857465097467
# [0]	train-logloss:0.645631	valid-logloss:0.645677
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [190]	train-logloss:0.016794	valid-logloss:0.021556
#
# 1
# 0.0154553656485 0.0215898110668
# [0]	train-logloss:0.646921	valid-logloss:0.647044
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [329]	train-logloss:0.033085	valid-logloss:0.044595
#
# 2
# 0.0317195384602 0.0447548010376
# [0]	train-logloss:0.644774	valid-logloss:0.644838
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [184]	train-logloss:0.004521	valid-logloss:0.008494
#
# 3
# 0.00368363841766 0.00863394500846
# [0]	train-logloss:0.647886	valid-logloss:0.647934
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [287]	train-logloss:0.0491	valid-logloss:0.056441
#
# 4
# 0.0475684412345 0.0564468736214
# [0]	train-logloss:0.64532	valid-logloss:0.645398
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [151]	train-logloss:0.015106	valid-logloss:0.021077
#
# 5
# 0.0138978763662 0.02110672761
# this fold avg train 0.0307223851221 avg val 0.0397131113485
# ========================
# all train avg 0.0309345993684 all val avg 0.0388278612891
#          id     toxic  severe_toxic   obscene    threat    insult  \
# 0   6044863  0.000876      0.000046  0.000249  0.000040  0.000407
# 1   6102620  0.000544      0.000044  0.000113  0.000036  0.000095
# 2  14563293  0.000163      0.000054  0.000147  0.000050  0.000107
# 3  21086297  0.001157      0.000046  0.000294  0.000062  0.000293
# 4  22982444  0.002432      0.000089  0.000430  0.000045  0.000325
#
#    identity_hate
# 0       0.000142
# 1       0.000082
# 2       0.000497
# 3       0.000148
# 4       0.000085
# save done

# %%
# xgb_res,b = simple_ens('xgb',k=8)
# sample_submission = pd.read_csv("../input/sample_submission.csv")
# sample_submission[list_classes] = xgb_res
# sample_submission.to_csv("../results/xgb_ens_new_csv_fold8.gz", index=False, compression='gzip')
# print(sample_submission.head())
# print('save done')
