# %%
import pickle
import glob
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss
import xgboost as xgb

# load feats
train_x,test_x = [],[]
for feat in sorted(glob.glob('../features/*.pkl')):
#     if 'tfidf' in feat or 'lr' in feat or 'mnb' in feat:
#         continue
    print('file path',feat)
    a,b = pickle.load(open(feat,'rb'))
    print(a.shape,b.shape)
    train_x.append(a)
    test_x.append(b)
train_x = np.nan_to_num(np.hstack(train_x))
test_x = np.nan_to_num(np.hstack(test_x))
print(train_x.shape)
    
# load y
train = pd.read_csv("../input/train.csv")
list_classes = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]
train_y = train[list_classes].values.astype('int')
print(train_x.shape)
# Out:
# /home/jac/.local/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# file path ../features/cnn_glove_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_gru_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_muse_adj_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_muse_adj_1_feat_de_fr.pkl
# (95851, 6) (226998, 6)
# file path ../features/cnn_muse_adj_2_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/gru_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lr_feat1.pkl
# (95851, 6) (226998, 6)
# file path ../features/lr_feat2.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_2_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj2_add_de_fr_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj3_add_de_fr_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj_1_add_de_fr_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj_2_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/lstm_muse_adj_bn_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/mnb_feat1.pkl
# (95851, 6) (226998, 6)
# file path ../features/mnb_feat2.pkl
# (95851, 6) (226998, 6)
# file path ../features/other_feat.pkl
# (95851, 16) (226998, 16)
# file path ../features/simple_rnn_muse_1_feat.pkl
# (95851, 6) (226998, 6)
# file path ../features/tfidf_feat1.pkl
# (95851, 30) (226998, 30)
# file path ../features/tfidf_feat2.pkl
# (95851, 30) (226998, 30)
# (95851, 202)
# (95851, 202)

# %%
from sklearn.model_selection import KFold
def simple_ens(model_name,k=3,rnd=233):
    kf = KFold(n_splits=k, shuffle=True, random_state=rnd)
    test_pred = np.zeros((226998,6))
    cache_test_pred = np.zeros((226998,6))
    single_best = 100
    single_best_pred = None
    all_train_loss_l,all_val_loss_l = 0,0
    
    for train_index, test_index in kf.split(train_x):
        # x,y
        curr_x,curr_y = train_x[train_index],train_y[train_index]
        hold_out_x,hold_out_y = train_x[test_index],train_y[test_index]
        val_loss_l,train_loss_l = 0,0
        d_test = xgb.DMatrix(test_x)
        
        # share params
        params = {
                'colsample_bytree': 0.75,
                'subsample': 0.75,
                'eta': 0.05,
                'max_depth': 3,
                'eval_metric':'logloss',
                'objective':'binary:logistic',
                'scale_pos_weight':0.75,
                'colsample_bylevel':0.75,
                'colsample_bytree':0.75,
            
                }
        
        # train for each class
        for i in range(6):
            d_train = xgb.DMatrix(curr_x, curr_y[:,i])
            d_valid = xgb.DMatrix(hold_out_x, hold_out_y[:,i])
            watchlist = [(d_train, 'train'), (d_valid, 'valid')]

            model = xgb.train(params, d_train, 1000, watchlist,
                              early_stopping_rounds=50,
                            verbose_eval=2000)
            print(i)
            try:
                curr_train_loss = log_loss(curr_y[:,i],model.predict(d_train))
                curr_val_loss = log_loss(hold_out_y[:,i],model.predict(d_valid))
                print(curr_train_loss,curr_val_loss)
                val_loss_l += curr_val_loss
                train_loss_l += curr_train_loss
            except:
                pass
            curr_test_pred = model.predict(d_test)
            
            test_pred[:,i] += curr_test_pred
            cache_test_pred[:,i] += curr_test_pred
            
        # avg 6 class
        train_loss_l = train_loss_l/6
        val_loss_l = val_loss_l/6
        print('this fold avg train',train_loss_l,'avg val',val_loss_l)
        
        # save best one fold result
        if val_loss_l < single_best:
            single_best = curr_val_loss
            single_best_pred = cache_test_pred
            print('new single best')
        
        cache_test_pred = np.zeros((226998,6))
        
        # avg k fold
        all_train_loss_l += train_loss_l/k
        all_val_loss_l += val_loss_l/k
        print('========================')
    test_pred = test_pred/k
    print('all train avg',all_train_loss_l,'all val avg',all_val_loss_l)
    return test_pred, single_best_pred

print('done')
# Out:
# done

# %%
xgb_res,b = simple_ens('xgb',k=5)
sample_submission = pd.read_csv("../input/sample_submission.csv")
sample_submission[list_classes] = xgb_res
sample_submission.to_csv("../results/xgb_adj_params_ens_new_csv_fold5.gz", index=False, compression='gzip')
print(sample_submission.head())
print('save done')
# Out:
# [0]	train-logloss:0.649416	valid-logloss:0.649369
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [327]	train-logloss:0.07477	valid-logloss:0.080527
#
# 0
# 0.073076590627 0.0807255855822
# [0]	train-logloss:0.645623	valid-logloss:0.645619
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [197]	train-logloss:0.017055	valid-logloss:0.0217
#
# 1
# 0.0156815905438 0.0218712218598
# [0]	train-logloss:0.646995	valid-logloss:0.646906
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [251]	train-logloss:0.037702	valid-logloss:0.042446
#
# 2
# 0.0361009804123 0.0425005681935
# [0]	train-logloss:0.644766	valid-logloss:0.644827
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [184]	train-logloss:0.004773	valid-logloss:0.008478
#
# 3
# 0.00393776038385 0.00869232222641
# [0]	train-logloss:0.647971	valid-logloss:0.647826
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [256]	train-logloss:0.051958	valid-logloss:0.055737
#
# 4
# 0.0503964010801 0.0558145851799
# [0]	train-logloss:0.645329	valid-logloss:0.645356
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [206]	train-logloss:0.015104	valid-logloss:0.018195
#
# 5
# 0.0139496932577 0.0182621627258
# this fold avg train 0.0321905027175 avg val 0.0379777409613
# new single best
# ========================
# [0]	train-logloss:0.649385	valid-logloss:0.649597
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [427]	train-logloss:0.06995	valid-logloss:0.087485
#
# 0
# 0.0684203495464 0.0874873435984
# [0]	train-logloss:0.64562	valid-logloss:0.645617
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [221]	train-logloss:0.016453	valid-logloss:0.021072
#
# 1
# 0.0152481816415 0.02118231406
# [0]	train-logloss:0.647005	valid-logloss:0.647187
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [215]	train-logloss:0.038188	valid-logloss:0.045583
#
# 2
# 0.0365433437448 0.0456284081545
# [0]	train-logloss:0.644782	valid-logloss:0.644805
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [165]	train-logloss:0.00529	valid-logloss:0.007673
#
# 3
# 0.00450054504267 0.00775802000222
# [0]	train-logloss:0.647884	valid-logloss:0.648062
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [292]	train-logloss:0.049445	valid-logloss:0.059835
#
# 4
# 0.0478979052916 0.059876728822
# [0]	train-logloss:0.645342	valid-logloss:0.645339
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [280]	train-logloss:0.013475	valid-logloss:0.017838
#
# 5
# 0.0123797636148 0.0179507827325
# this fold avg train 0.0308316814803 avg val 0.0399805995616
# ========================
# [0]	train-logloss:0.649406	valid-logloss:0.649406
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [443]	train-logloss:0.070584	valid-logloss:0.083302
#
# 0
# 0.0690378531997 0.0834655009274
# [0]	train-logloss:0.645615	valid-logloss:0.645627
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [202]	train-logloss:0.016761	valid-logloss:0.021833
#
# 1
# 0.0154610770827 0.0219444121922
# [0]	train-logloss:0.647091	valid-logloss:0.647125
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [358]	train-logloss:0.034269	valid-logloss:0.044588
#
# 2
# 0.0329921363487 0.0446795555615
# [0]	train-logloss:0.644763	valid-logloss:0.644799
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [166]	train-logloss:0.005096	valid-logloss:0.008923
#
# 3
# 0.00428178525118 0.00899741299035
# [0]	train-logloss:0.647916	valid-logloss:0.647956
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [385]	train-logloss:0.046725	valid-logloss:0.060645
#
# 4
# 0.0453103099991 0.0607286467123
# [0]	train-logloss:0.645312	valid-logloss:0.645367
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [196]	train-logloss:0.014751	valid-logloss:0.021199
#
# 5
# 0.0135444179219 0.0213378900551
# this fold avg train 0.0301045966339 avg val 0.0401922364065
# ========================
# [0]	train-logloss:0.649387	valid-logloss:0.649465
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [505]	train-logloss:0.068621	valid-logloss:0.084578
#
# 0
# 0.067214841808 0.0845805337937
# [0]	train-logloss:0.645578	valid-logloss:0.645673
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [215]	train-logloss:0.016207	valid-logloss:0.021994
#
# 1
# 0.0150104363564 0.0221136456221
# [0]	train-logloss:0.647062	valid-logloss:0.647131
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [168]	train-logloss:0.039994	valid-logloss:0.045749
#
# 2
# 0.0382169499328 0.0458103584224
# [0]	train-logloss:0.644773	valid-logloss:0.64482
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [172]	train-logloss:0.005068	valid-logloss:0.007701
#
# 3
# 0.00424158467951 0.00787134130943
# [0]	train-logloss:0.647907	valid-logloss:0.647933
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [349]	train-logloss:0.048397	valid-logloss:0.057805
#
# 4
# 0.0469282401219 0.057865530037
# [0]	train-logloss:0.645335	valid-logloss:0.645403
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [184]	train-logloss:0.015225	valid-logloss:0.019589
#
# 5
# 0.0139538944279 0.0197644734228
# this fold avg train 0.0309276578877 avg val 0.0396676471013
# ========================
# [0]	train-logloss:0.649342	valid-logloss:0.649481
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [238]	train-logloss:0.076328	valid-logloss:0.087241
#
# 0
# 0.0743952304241 0.0873053870045
# [0]	train-logloss:0.645607	valid-logloss:0.645681
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [228]	train-logloss:0.016198	valid-logloss:0.021536
#
# 1
# 0.0149719277014 0.0216230623013
# [0]	train-logloss:0.647052	valid-logloss:0.647108
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [271]	train-logloss:0.036587	valid-logloss:0.045497
#
# 2
# 0.0351035727904 0.0455876827902
# [0]	train-logloss:0.644769	valid-logloss:0.644781
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [206]	train-logloss:0.004506	valid-logloss:0.007625
#
# 3
# 0.00370329018129 0.0078001755895
# [0]	train-logloss:0.64788	valid-logloss:0.647939
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [387]	train-logloss:0.046915	valid-logloss:0.060015
#
# 4
# 0.0455414631199 0.060167421474
# [0]	train-logloss:0.645318	valid-logloss:0.64535
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [165]	train-logloss:0.015576	valid-logloss:0.020849
#
# 5
# 0.0143014009122 0.0209860116756
# this fold avg train 0.0313361475215 avg val 0.0405782901392
# ========================
# all train avg 0.0310781172482 all val avg 0.039679302834
#          id     toxic  severe_toxic   obscene    threat    insult  \
# 0   6044863  0.000950      0.000041  0.000434  0.000046  0.000465
# 1   6102620  0.000879      0.000041  0.000146  0.000034  0.000103
# 2  14563293  0.000287      0.000065  0.000141  0.000065  0.000091
# 3  21086297  0.001274      0.000055  0.000425  0.000054  0.000345
# 4  22982444  0.001878      0.000088  0.000317  0.000059  0.000186
#
#    identity_hate
# 0       0.000128
# 1       0.000087
# 2       0.000368
# 3       0.000158
# 4       0.000077
# save done

# %%
# xgb_res,b = simple_ens('xgb',k=8)
# sample_submission = pd.read_csv("../input/sample_submission.csv")
# sample_submission[list_classes] = xgb_res
# sample_submission.to_csv("../results/xgb_ens_new_csv_fold8.gz", index=False, compression='gzip')
# print(sample_submission.head())
# print('save done')
